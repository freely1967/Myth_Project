# %%
# !pip install pandas networkx pyvis

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network

# Load the CSV file you downloaded from Wikidata
df = pd.read_csv('myth_query252.csv')  # Change name if needed

# Create a directed graph
G = nx.DiGraph()

# Add nodes with types and edges with relation labels
for _, row in df.iterrows():
    char1 = row['char1Label']
    char2 = row['char2Label']
    rel = row['relationLabel']
    type1 = row.get('char1TypeLabel', 'Unknown')
    type2 = row.get('char2TypeLabel', 'Unknown')

    G.add_node(char1, type=type1)
    G.add_node(char2, type=type2)
    G.add_edge(char1, char2, label=rel)

# Use PyVis to generate interactive HTML graph
net = Network(notebook=True, height="750px", width="100%", directed=True)
net.from_nx(G)

# Optional: Add labels and titles
for node in net.nodes:
    node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type')})"
    node['label'] = node['id']

for edge in net.edges:
    edge['title'] = edge['label']

# Show the graph in the notebook
net.show("mythology_graph.html")

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network

# Load the CSV file you downloaded from Wikidata
df = pd.read_csv('myth_query252.csv')  # Change name if needed

# Create a directed graph
G = nx.DiGraph()

# Add nodes with types and edges with relation labels
for _, row in df.iterrows():
    char1 = row['char1Label']
    char2 = row['char2Label']
    rel = row['relationLabel']
    type1 = row.get('char1TypeLabelSample', 'Unknown')  # Change to 'char1TypeLabelSample'
    type2 = row.get('char2TypeLabelSample', 'Unknown')  # Change to 'char2TypeLabelSample'

    G.add_node(char1, type=type1)
    G.add_node(char2, type=type2)
    G.add_edge(char1, char2, label=rel)

# Use PyVis to generate interactive HTML graph
net = Network(notebook=True, height="750px", width="100%", directed=True)
net.from_nx(G)

# Optional: Add labels and titles to the nodes
for node in net.nodes:
    node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type')})"  # Show type in tooltip
    node['label'] = node['id']  # Show character name as label

# Optional: Add titles to the edges
for edge in net.edges:
    edge['title'] = edge['label']  # Show relation on hover

# Show the graph in the notebook
net.show("mythology_graph.html")

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network

# Load the CSV file you downloaded from Wikidata
df = pd.read_csv('myth_query1358with.csv')  # Change name if needed

# Create a directed graph
G = nx.DiGraph()

# Add nodes with types and edges with relation labels
for _, row in df.iterrows():
    char1 = row['char1Label']
    char2 = row['char2Label']
    rel = row['relationLabel']
    type1 = row.get('char1Type', 'Unknown')  # Use 'char1Type'
    type2 = row.get('char2Type', 'Unknown')  # Use 'char2Type'

    G.add_node(char1, type=type1)
    G.add_node(char2, type=type2)
    G.add_edge(char1, char2, label=rel)

# Use PyVis to generate interactive HTML graph
net = Network(notebook=True, height="750px", width="100%", directed=True)
net.from_nx(G)

# Optional: Add labels and titles to the nodes
for node in net.nodes:
    # Include char1/char2 name and type in the tooltip
    node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type')})"
    # Use char1Label/char2Label as the label for nodes
    node['label'] = node['id']

# Optional: Add titles to the edges
for edge in net.edges:
    # Include the relation in the edge's tooltip
    edge['title'] = edge['label']  # Show relation on hover

# Show the graph in the notebook
net.show("mythology_graph.html")

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network

# Load the CSV file you downloaded from Wikidata
df = pd.read_csv('myth_query1358with.csv')  # Change name if needed

# Create a directed graph
G = nx.DiGraph()

# Add nodes with types and edges with relation labels
for _, row in df.iterrows():
    char1 = row['char1Label']
    char2 = row['char2Label']
    rel = row['relationLabel']
    type1 = row.get('char1Type', 'Unknown')  # Use 'char1Type'
    type2 = row.get('char2Type', 'Unknown')  # Use 'char2Type'

    G.add_node(char1, type=type1)
    G.add_node(char2, type=type2)
    G.add_edge(char1, char2, label=rel)

# Use PyVis to generate interactive HTML graph
net = Network(notebook=True, height="750px", width="100%", directed=True)
net.from_nx(G)

# Optional: Add labels and titles to the nodes
for node in net.nodes:
    # Include char1/char2 name and type in the tooltip
    node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type')})"
    # Use char1Label/char2Label as the label for nodes
    node['label'] = node['id']

# Optional: Add titles to the edges
for edge in net.edges:
    # Include the relation in the edge's tooltip
    edge['title'] = edge['label']  # Show relation on hover

# Show the graph in the notebook
net.show("mythology_graph.html")
# Out:
# ...
# mythology_graph.html
#         <iframe
#             width="100%"
#             height="750px"
#             src="mythology_graph.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network

# Load the CSV file you downloaded from Wikidata
df = pd.read_csv('myth_query1358with.csv')  # Change name if needed

# Create a directed graph
G = nx.DiGraph()

# Add nodes with types and edges with relation labels
for _, row in df.iterrows():
    char1 = row['char1Label']
    char2 = row['char2Label']
    rel = row['relationLabel']
    type1 = row.get('char1Type', 'Unknown')  # Change to 'char1TypeLabelSample'
    type2 = row.get('char2Type', 'Unknown')  # Change to 'char2TypeLabelSample'

    G.add_node(char1, type=type1)
    G.add_node(char2, type=type2)
    G.add_edge(char1, char2, label=rel)

# Use PyVis to generate interactive HTML graph
net = Network(notebook=True, height="750px", width="100%", directed=True)
net.from_nx(G)

# Optional: Add labels and titles to the nodes
for node in net.nodes:
    node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type')})"  # Show type in tooltip
    node['label'] = node['id']  # Show character name as label

# Optional: Add titles to the edges
for edge in net.edges:
    edge['title'] = edge['label']  # Show relation on hover

# Show the graph in the notebook
net.show("mythology_graph.html")
# Save to a specific file path (replace with your desired path)
#net.save_graph("C:/Users/dilar/Downloads/mythology_graph.html")
# Save in the current working directory
#net.save_graph("mythology_graph.html")

# %%
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd

df = pd.read_csv("myth_query1358with.csv")
G = nx.DiGraph()

for _, row in df.iterrows():
    G.add_node(row['char1Label'])
    G.add_node(row['char2Label'])
    G.add_edge(row['char1Label'], row['char2Label'], label=row['relationLabel'])

plt.figure(figsize=(20, 20))
pos = nx.spring_layout(G, k=0.5)
nx.draw(G, pos, with_labels=True, node_size=50, font_size=8, arrows=True)
plt.savefig("mythology_graph_static.png", dpi=300)
plt.show()

# %%
import pandas as pd
import networkx as nx
from pyvis.network import Network

# Load your CSV
df = pd.read_csv('myth_query1358with.csv')  # Replace with your actual filename

# Create directed graph
G = nx.DiGraph()

# Build nodes and edges
for _, row in df.iterrows():
    char1 = row['char1Label']
    char2 = row['char2Label']
    rel = row['relationLabel']
    type1 = row.get('char1Type', 'Unknown')
    type2 = row.get('char2Type', 'Unknown')

    G.add_node(char1, type=type1)
    G.add_node(char2, type=type2)
    G.add_edge(char1, char2, label=rel)

# Initialize PyVis network
net = Network(notebook=True, height="750px", width="100%", directed=True)
net.from_nx(G)

# Customize node and edge titles
for node in net.nodes:
    node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type')})"
    node['label'] = node['id']

for edge in net.edges:
    edge['title'] = edge['label']

# 🔧 Add physics settings to stabilize and reduce movement
net.set_options("""
var options = {
  "physics": {
    "stabilization": {
      "enabled": true,
      "iterations": 1000,
      "updateInterval": 25
    },
    "barnesHut": {
      "gravitationalConstant": -8000,
      "springLength": 200
    }
  }
}
""")

# Show and save the interactive graph
net.show("mythology_graph.html")

# %%
import ipywidgets as widgets
from IPython.display import display, HTML
from pyvis.network import Network
import networkx as nx

# Assuming the graph is already created and saved as `G`
# Example: G = nx.read_gpickle("mythology_graph.gpickle")

def show_character_connections(G, character_name):
    if character_name not in G.nodes:
        print(f"{character_name} not found in the graph.")
        return

    # Create a subgraph of neighbors (both directions)
    neighbors = set(G.successors(character_name)) | set(G.predecessors(character_name))
    sub_nodes = {character_name} | neighbors
    subgraph = G.subgraph(sub_nodes).copy()

    # Create the network graph for PyVis
    net = Network(notebook=True, height="750px", width="100%", directed=True)
    net.from_nx(subgraph)

    # Add titles and labels for each node
    for node in net.nodes:
        node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type', 'Unknown')})"
        node['label'] = node['id']

    # Add titles for the edges (relations)
    for edge in net.edges:
        edge['title'] = edge['label']

    # Show the graph directly in the notebook
    net.show('character_connections.html')
    # Display the graph inline
    display(HTML('character_connections.html'))

# Create a widget to input a character's name
character_input = widgets.Text(
    value='',
    placeholder='Type character name',
    description='Character:',
    disabled=False
)

# Create a button to search and show the graph
search_button = widgets.Button(description="Show Connections")

# Define the function for button click
def on_button_click(b):
    character_name = character_input.value
    if character_name:
        show_character_connections(G, character_name)
    else:
        print("Please enter a character name.")

# Link the button with the function
search_button.on_click(on_button_click)

# Display the widgets
display(character_input, search_button)

# %%
import ipywidgets as widgets
from IPython.display import display, HTML
from pyvis.network import Network
import networkx as nx

# Assuming the graph is already created and saved as `G`
# Example: G = nx.read_gpickle("mythology_graph.gpickle")

def show_character_connections(G, character_name):
    if character_name not in G.nodes:
        print(f"{character_name} not found in the graph.")
        return

    # Create a subgraph of neighbors (both directions)
    neighbors = set(G.successors(character_name)) | set(G.predecessors(character_name))
    sub_nodes = {character_name} | neighbors
    subgraph = G.subgraph(sub_nodes).copy()

    # Create the network graph for PyVis
    net = Network(notebook=True, height="750px", width="100%", directed=True)
    net.from_nx(subgraph)

    # Add titles and labels for each node
    for node in net.nodes:
        node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type', 'Unknown')})"
        node['label'] = node['id']

    # Add titles for the edges (relations)
    for edge in net.edges:
        edge['title'] = edge['label']

    # Display the graph directly in the notebook (without saving it as HTML)
    net.show(f"{character_name}_connections.html")  # This generates the HTML output
    display(HTML(f"{character_name}_connections.html"))  # This will display it inline

# Get user input directly in the program
character_name = input("Enter the mythological character's name: ")  # Change this to use the desired input method

if character_name:
    show_character_connections(G, character_name)
else:
    print("No character name entered.")

# %%
####
from pyvis.network import Network

def show_character_connections(G):
    # Prompt the user to enter a character's name
    character_name = input("Search for the mythological character you want to learn the connections for: ")

    if character_name not in G.nodes:
        print(f"{character_name} not found in the graph.")
        return

    # Create a subgraph of neighbors (both directions)
    neighbors = set(G.successors(character_name)) | set(G.predecessors(character_name))
    sub_nodes = {character_name} | neighbors
    subgraph = G.subgraph(sub_nodes).copy()

    # Create the network graph for PyVis
    net = Network(notebook=True, height="750px", width="100%", directed=True)
    net.from_nx(subgraph)

    # Add titles and labels for each node
    for node in net.nodes:
        node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type', 'Unknown')})"
        node['label'] = node['id']

    # Add titles for the edges (relations)
    for edge in net.edges:
        edge['title'] = edge.get('label', '')

    # Show the graph as an interactive HTML file
    net.show(f"{character_name}_connections.html")

# Run the function to start the interaction
show_character_connections(G)

# %%
import ipywidgets as widgets
from IPython.display import display, HTML
import networkx as nx

# Function to get the list of relations for a given character
def get_character_relations(G, character_name):
    if character_name not in G.nodes:
        print(f"{character_name} not found in the graph.")
        return []

    relations = []

    # Get all outgoing and incoming edges for the character (both directions)
    for neighbor in G.successors(character_name):
        relation = G.get_edge_data(character_name, neighbor)
        relations.append(f"{character_name} {relation['label']} {neighbor}")

    for neighbor in G.predecessors(character_name):
        relation = G.get_edge_data(neighbor, character_name)
        relations.append(f"{neighbor} {relation['label']} {character_name}")

    return relations

# Function to display the relations in a readable format
def show_character_relations(G, character_name):
    relations = get_character_relations(G, character_name)
    if not relations:
        print(f"No connections found for {character_name}.")
    else:
        print(f"Connections for {character_name}:")
        for rel in relations:
            print(rel)

# Prompt user for character name
character_name = input("Enter the mythological character's name: ")

# Example graph loading (use the actual graph `G` here)
# G = nx.read_gpickle("mythology_graph.gpickle")

if character_name:
    show_character_relations(G, character_name)
else:
    print("No character name entered.")

# %%
import ipywidgets as widgets
from IPython.display import display
import networkx as nx

# Function to get the list of relations for a given character
def get_character_relations(G, character_name):
    if character_name not in G.nodes:
        print(f"{character_name} not found in the graph.")
        return []

    relations = {"Spouse": [], "Sibling": [], "Mother": [], "Father": [], "Killed by": [], "Other": []}

    # Get all outgoing and incoming edges for the character (both directions)
    for neighbor in G.successors(character_name):
        relation = G.get_edge_data(character_name, neighbor)
        label = relation['label'].lower()
        if "spouse" in label:
            relations["Spouse"].append(f"{character_name} {relation['label']} {neighbor}")
        elif "sibling" in label:
            relations["Sibling"].append(f"{character_name} {relation['label']} {neighbor}")
        elif "mother" in label:
            relations["Mother"].append(f"{character_name} {relation['label']} {neighbor}")
        elif "father" in label:
            relations["Father"].append(f"{character_name} {relation['label']} {neighbor}")
        elif "killed" in label:
            relations["Killed by"].append(f"{character_name} {relation['label']} {neighbor}")
        else:
            relations["Other"].append(f"{character_name} {relation['label']} {neighbor}")

    for neighbor in G.predecessors(character_name):
        relation = G.get_edge_data(neighbor, character_name)
        label = relation['label'].lower()
        if "spouse" in label:
            relations["Spouse"].append(f"{neighbor} {relation['label']} {character_name}")
        elif "sibling" in label:
            relations["Sibling"].append(f"{neighbor} {relation['label']} {character_name}")
        elif "mother" in label:
            relations["Mother"].append(f"{neighbor} {relation['label']} {character_name}")
        elif "father" in label:
            relations["Father"].append(f"{neighbor} {relation['label']} {character_name}")
        elif "killed" in label:
            relations["Killed by"].append(f"{neighbor} {relation['label']} {character_name}")
        else:
            relations["Other"].append(f"{neighbor} {relation['label']} {character_name}")

    return relations

# Function to display the relations in a readable format
def show_character_relations(G, character_name):
    relations = get_character_relations(G, character_name)
    if not any(relations.values()):
        print(f"No connections found for {character_name}.")
    else:
        print(f"### Connections for {character_name}:")

        for relation_type, relation_list in relations.items():
            if relation_list:
                print(f"\n--- **{relation_type}:** ---")
                for rel in relation_list:
                    print(f"- {rel}")

# Create the input widget
character_name = input("Enter the mythological character's name: ")

# Example graph loading (use the actual graph `G` here)
# G = nx.read_gpickle("mythology_graph.gpickle")

if character_name:
    show_character_relations(G, character_name)
else:
    print("No character name entered.")

# %%
#bu degil
import pandas as pd
import networkx as nx
from pyvis.network import Network

# Load the CSV file you downloaded from Wikidata
df = pd.read_csv('myth_query252.csv')  # Change name if needed

# Create a directed graph
G = nx.DiGraph()

# Add nodes with types and edges with relation labels
for _, row in df.iterrows():
    char1 = row['char1Label']
    char2 = row['char2Label']
    rel = row['relationLabel']
    type1 = row.get('char1TypeLabel', 'Unknown')  # Change to 'char1TypeLabelSample'
    type2 = row.get('char2TypeLabel', 'Unknown')  # Change to 'char2TypeLabelSample'

    G.add_node(char1, type=type1)
    G.add_node(char2, type=type2)
    G.add_edge(char1, char2, label=rel)

# Use PyVis to generate interactive HTML graph
net = Network(notebook=True, height="750px", width="100%", directed=True)
net.from_nx(G)

# Optional: Add labels and titles to the nodes
for node in net.nodes:
    node['title'] = f"{node['id']} ({G.nodes[node['id']].get('type')})"  # Show type in tooltip
    node['label'] = node['id']  # Show character name as label

# Optional: Add titles to the edges
for edge in net.edges:
    edge['title'] = edge['label']  # Show relation on hover

# Show the graph in the notebook
net.show("mythology_graph252.html")
# Save to a specific file path (replace with your desired path)
#net.save_graph("C:/Users/dilar/Downloads/mythology_graph.html")
# Save in the current working directory
net.save_graph("mythology_graph252.html")

# %%
## pagerank
import networkx as nx

# Assuming your graph is already created as G
# Calculate PageRank
pagerank_scores = nx.pagerank(G)

# Sort and display the top N most important characters
top_n = 10
top_characters = sorted(pagerank_scores.items(), key=lambda x: x[1], reverse=True)[:top_n]

print(f"Top {top_n} mythological characters by PageRank:")
for i, (char, score) in enumerate(top_characters, start=1):
    print(f"{i}. {char}: {score:.4f}")

# %%
import networkx as nx

# Load your graph here
# G = nx.read_gpickle("mythology_graph.gpickle")

def explain_relation_undirected(G, node1, node2):
    """
    Tries to find the relationship and direction between node1 and node2 in the original directed graph G.
    """
    if G.has_edge(node1, node2):
        relation = G[node1][node2].get('label', 'related to')
        return f"{node2} is the {relation} of {node1}"
    elif G.has_edge(node2, node1):
        relation = G[node2][node1].get('label', 'related to')
        # Invert some relationships
        if relation == "mother":
            return f"{node2} is the child of {node1}"
        elif relation == "father":
            return f"{node2} is the child of {node1}"
        elif relation in ["spouse", "sibling"]:
            return f"{node2} is the {relation} of {node1}"
        else:
            return f"{node1} is related to {node2} via '{relation}'"
    else:
        return f"No relation found between {node1} and {node2}"

def find_shortest_path_undirected(G, source, target):
    if source not in G or target not in G:
        return [f"One or both characters not found in the graph: {source}, {target}"]

    try:
        undirected_G = G.to_undirected()
        path = nx.shortest_path(undirected_G, source=source, target=target)

        results = [f"Undirected shortest path between {source} and {target}:\n"]
        for i in range(len(path) - 1):
            explanation = explain_relation_undirected(G, path[i], path[i + 1])
            results.append(explanation)
        results.append(f"\nTotal steps: {len(path) - 1}")
        return results
    except nx.NetworkXNoPath:
        return [f"No path found between {source} and {target}."]


# Get user input
source = input("Enter the name of the first character: ").strip()
target = input("Enter the name of the second character: ").strip()

# Run the function
find_shortest_path_undirected(G, source, target)
# Out:
# ['Undirected shortest path between Zeus and Hera:\n',
#  'Hera is the spouse of Zeus',
#  '\nTotal steps: 1']

# %%
import networkx as nx

def explain_relation_undirected(G, node1, node2):
    """
    Tries to find the relationship and direction between node1 and node2 in the original directed graph G.
    """
    if G.has_edge(node1, node2):
        relation = G[node1][node2].get('label', 'related to')
        return f"{node2} is the {relation} of {node1}"
    elif G.has_edge(node2, node1):
        relation = G[node2][node1].get('label', 'related to')
        # Invert some relationships
        if relation == "mother":
            return f"{node2} is the child of {node1}"
        elif relation == "father":
            return f"{node2} is the child of {node1}"
        elif relation in ["spouse", "sibling"]:
            return f"{node2} is the {relation} of {node1}"
        else:
            return f"{node1} is related to {node2} via '{relation}'"
    else:
        return f"No relation found between {node1} and {node2}"

def find_shortest_path_undirected(G, source, target):
    """
    Returns a list of strings explaining the shortest path between source and target in undirected form.
    """
    if source not in G or target not in G:
        return [f"One or both characters not found in the graph: {source}, {target}"]

    try:
        undirected_G = G.to_undirected()
        path = nx.shortest_path(undirected_G, source=source, target=target)

        results = [f"Undirected shortest path between {source} and {target}:\n"]
        for i in range(len(path) - 1):
            explanation = explain_relation_undirected(G, path[i], path[i + 1])
            results.append(explanation)
        results.append(f"\nTotal steps: {len(path) - 1}")
        return results
    except nx.NetworkXNoPath:
        return [f"No path found between {source} and {target}."]

# %%
import tkinter as tk
from tkinter import messagebox
import pandas as pd
import networkx as nx

# --- Load and build the graph ---
df = pd.read_csv("myth_query252.csv")
G = nx.DiGraph()
metadata = {}

for _, row in df.iterrows():
    char1 = row["char1Label"].strip()
    char2 = row["char2Label"].strip()
    relation = row["relationLabel"].strip()
    G.add_edge(char1, char2, label=relation)
    metadata[char1] = row["char1TypeLabelSample"].strip()
    metadata[char2] = row["char2TypeLabelSample"].strip()

# --- Matching logic with weights ---
def match_character(preferences, weights, filter_term):
    scores = {}
    explanations = {}

    for node in G.nodes():
        if filter_term and filter_term.lower() not in metadata.get(node, '').lower():
            continue

        children = sum(1 for _, _, d in G.out_edges(node, data=True) if d['label'] == "father")
        kills = sum(1 for _, _, d in G.out_edges(node, data=True) if d['label'] == "killed")
        spouses = sum(1 for _, _, d in G.out_edges(node, data=True) if d['label'] == "spouse")
        out_total = G.out_degree(node)
        in_total = G.in_degree(node)

        actual_values = [children, kills, spouses, in_total, out_total]
        score = 0
        for pref, weight, actual in zip(preferences, weights, actual_values):
            score += weight * (10 - abs(pref - actual))  # Closer match = higher score

        explanation = (
            f"Children: {children}, Kills: {kills}, Spouses: {spouses}, "
            f"Outdegree: {out_total}, Indegree: {in_total}, Score: {score}"
        )

        scores[node] = score
        explanations[node] = explanation

    sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
    return [(name, scores[name], metadata.get(name, "Unknown"), explanations[name]) for name, _ in sorted_scores]

# --- UI Setup ---
root = tk.Tk()
root.title("Mythology Character Matcher")
root.geometry("800x600")

# Configure grid for responsiveness
root.columnconfigure(0, weight=1)
root.rowconfigure(0, weight=1)

main_frame = tk.Frame(root, padx=10, pady=10)
main_frame.grid(sticky="nsew")
main_frame.columnconfigure(0, weight=1)
main_frame.rowconfigure(7, weight=1)

labels = [
    "1. Desire for many children",
    "2. Desire to kill",
    "3. Desire for many spouses",
    "4. Desire for popularity (indegree)",
    "5. Desire for influence (outdegree)",
]

pref_entries = []
weight_entries = []

# Header
tk.Label(main_frame, text="Preferences and Importance (0–10)", font=("Helvetica", 14)).grid(row=0, column=0, columnspan=5, pady=10)

# Input fields
for i, lbl in enumerate(labels):
    tk.Label(main_frame, text=lbl, anchor="w").grid(row=i+1, column=0, sticky="w", padx=5)
    tk.Label(main_frame, text="Preference:").grid(row=i+1, column=1)
    pref = tk.Entry(main_frame, width=5)
    pref.grid(row=i+1, column=2)
    pref_entries.append(pref)

    tk.Label(main_frame, text="Weight:").grid(row=i+1, column=3)
    weight = tk.Entry(main_frame, width=5)
    weight.grid(row=i+1, column=4)
    weight_entries.append(weight)

# Filter
tk.Label(main_frame, text="Filter by type (optional):").grid(row=6, column=0, columnspan=2, sticky="w", pady=(10, 0))
filter_entry = tk.Entry(main_frame)
filter_entry.grid(row=6, column=2, columnspan=3, sticky="ew", pady=(10, 0))

# Output Text Box
output = tk.Text(main_frame, wrap="word")
output.grid(row=7, column=0, columnspan=5, sticky="nsew", pady=(10, 0))

# Make output area resizable
main_frame.rowconfigure(7, weight=1)
main_frame.columnconfigure(4, weight=1)

# Button
def on_submit():
    try:
        prefs = [int(entry.get()) for entry in pref_entries]
        weights = [int(entry.get()) for entry in weight_entries]
        if any(p < 1 or p > 10 for p in prefs) or any(w < 0 or w > 10 for w in weights):
            raise ValueError
    except:
        messagebox.showerror("Invalid Input", "Preferences must be 1–10. Weights must be 0–10.")
        return

    filter_term = filter_entry.get().strip()
    result = match_character(prefs, weights, filter_term)

    output.delete(1.0, tk.END)
    output.insert(tk.END, "Top Matches (with Type & Score):\n\n")
    for i, (name, score, ctype, reason) in enumerate(result[:5], 1):
        output.insert(tk.END, f"{i}. {name} ({ctype}) — Score: {score}\n")
        output.insert(tk.END, f"    {reason}\n\n")

tk.Button(main_frame, text="Find Best Match", command=on_submit).grid(row=8, column=0, columnspan=5, pady=10)

root.mainloop()
